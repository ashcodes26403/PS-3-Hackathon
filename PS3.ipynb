# %% [markdown]
# #Importing the relevant libraries

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re

# %%
df = pd.read_csv('PS3_train.csv') # Loading the dataset

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stemmer=PorterStemmer()

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# !pip install gensim
# !pip install python-Levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.0/174.0 KB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 32.7 MB/s eta 0:00:00
# ...

# %%
import gensim

# %%
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
stop_words = nlp.Defaults.stop_words
print(stop_words)
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# ...

# %%
from gensim.models import Word2Vec , KeyedVectors #importing Word2Vec

# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')
# Out:
# [=================================================-] 99.9% 1660.6/1662.8MB downloaded

# %%
def spacy_tokenizer(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    doc = nlp(sentence)



    # print(doc)
    # print(type(doc))

    # Lemmatizing each token and converting each token into lowercase
    mytokens = [ word.lemma_.lower().strip() for word in doc ]

    # print(mytokens)

    # Removing stop words
    mytokens = [ word for word in mytokens]

    # return preprocessed list of tokens
    return mytokens

# %%
def sent_vec(sent):                # To encode the tokens of the content and title
  vector_size = wv.vector_size
  wv_res = np.zeros(vector_size)
  ctr = 1
  for w in sent:
    if w in wv:
      ctr += 1
      wv_res += wv[w]
  wv_res = wv_res/ctr
  return wv_res

# %%
df['tokens'] = df['content'].apply(spacy_tokenizer)

# %%
df
# Out:
#                                                  content  \
# 0      Premium quality five pocket jean from Wrangler...
# 1      If you're looking for a different kind of anim...
# 2      First things first: Yes, Thinking XXX features...
# 3      Feathertouch. 100% Polyester Machine Wash Warm...
# 4      When you need outstanding fuel delivery, easy ...
# ...                                                  ...
# 35107  SArah Walker, Anthony Rolfe Johnson, Jean Rigb...
# 35108  Buy Teenage Mutant Ninja Turtles 4: Turtles in...
# 35109  A 10 movie collection of women action flicks. ...
# 35110  This huarache sandal is designed for all-day c...
# 35111  The Wrangler Cowboy Cut jean is a Western Wear...
#
#                                                    title         uid  \
# 0      Amazon.com: Wrangler Men's Rugged Wear Relaxed...  B0000CBALT
# 1      Sakura Diaries - Complete Series Collector's E...  B00005QFDT
# 2                     Thinking XXX (Extended Cut) (2006)  B000BNXD50
# ...

# %%
df['vec'] = df['tokens'].apply(sent_vec)

# %%
len(df['vec'][0])
# Out:
# 300

# %%
df
# Out:
#                                                  content  \
# 0      Premium quality five pocket jean from Wrangler...
# 1      If you're looking for a different kind of anim...
# 2      First things first: Yes, Thinking XXX features...
# 3      Feathertouch. 100% Polyester Machine Wash Warm...
# 4      When you need outstanding fuel delivery, easy ...
# ...                                                  ...
# 35107  SArah Walker, Anthony Rolfe Johnson, Jean Rigb...
# 35108  Buy Teenage Mutant Ninja Turtles 4: Turtles in...
# 35109  A 10 movie collection of women action flicks. ...
# 35110  This huarache sandal is designed for all-day c...
# 35111  The Wrangler Cowboy Cut jean is a Western Wear...
#
#                                                    title         uid  \
# 0      Amazon.com: Wrangler Men's Rugged Wear Relaxed...  B0000CBALT
# 1      Sakura Diaries - Complete Series Collector's E...  B00005QFDT
# 2                     Thinking XXX (Extended Cut) (2006)  B000BNXD50
# ...

# %% [markdown]
# # We encode the content tokens above, now we'll do the same for the title tokens

# %%
df['tokens2'] = df['title'].apply(spacy_tokenizer)

# %%
df['vec2'] = df['tokens2'].apply(sent_vec)

# %% [markdown]
# ## Here we add the encodings of the title to that of content to give equal weightage to both of them as the product title and description is equally important to correctly classify the product

# %%
df['vec'] += df['vec2']

# %%
x_train_df = df['vec']       # Tr

# %%
y_train_df = df['target_ind']

# %% [markdown]
# #Importing Libraries for our neural network

# %%
import os

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt

# %%
n_inputs=10

# %%
y_train_df = y_train_df
# Out:
# 0        247
# 1        453
# 2        228
# 3        223
# 4        312
#         ...
# 35107    473
# 35108     74
# 35109    460
# 35110    158
# 35111    340
# Name: target_ind, Length: 35112, dtype: int64

# %%
class Net(torch.nn.Module):
    def __init__(self, n_feature, n_hidden, n_output):
        super(Net, self).__init__()
        self.hidden = torch.nn.Linear(n_feature, n_hidden)   # hidden layer
        self.relu =  torch.nn.ReLU(inplace=True)
        self.out = torch.nn.Linear(n_hidden, n_output)   # output layer
        #self.softmax = torch.nn.Softmax()
    def forward(self, x):
        x = self.hidden(x)      # activation function for hidden layer
        x = self.relu(x)
        x = self.out(x)
        #x = self.softmax(x)
        return x

# %% [markdown]
# # Architecture of our model

# %%
our_model = Net(300, 512, 500)

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(our_model.parameters(), lr=0.01)

# %%
len(final_tensor)
# Out:
# 35112

# %%
for epoch in range(500):  # loop over the dataset multiple times

    #running_loss = 0.0
    #for i in range(0, len(torch_tensor)):
        # get the inputs; data is a list of [inputs, labels]
        #inputs, labels = data

        # zero the parameter gradients


    # forward + backward + optimize
    outputs = our_model(torch_tensor.to(torch.float32))
    optimizer.zero_grad()
    loss = criterion(outputs, target_tensor.squeeze(dim=1).type(torch.long))
    loss.backward()
    optimizer.step()


    # print statistics
    loss += loss.item()
        # print every 2000 mini-batches
    print(f'[{epoch + 1}] loss: {loss:.3f}')
    #running_loss = 0.0

print('Finished Training')
# Out:
# [1] loss: 1.639
# [2] loss: 1.629
# [3] loss: 1.621
# [4] loss: 1.612
# [5] loss: 1.599
# [6] loss: 1.581
# [7] loss: 1.564
# [8] loss: 1.547
# [9] loss: 1.534
# [10] loss: 1.523
# [11] loss: 1.514
# [12] loss: 1.505
# [13] loss: 1.496
# [14] loss: 1.486
# [15] loss: 1.474
# [16] loss: 1.462
# [17] loss: 1.450
# [18] loss: 1.439
# [19] loss: 1.428
# [20] loss: 1.418
# [21] loss: 1.410
# [22] loss: 1.402
# [23] loss: 1.396
# [24] loss: 1.392
# [25] loss: 1.386
# [26] loss: 1.380
# [27] loss: 1.369
# [28] loss: 1.360
# [29] loss: 1.354
# [30] loss: 1.350
# [31] loss: 1.346
# [32] loss: 1.340
# [33] loss: 1.326
# [34] loss: 1.314
# [35] loss: 1.303
# [36] loss: 1.295
# [37] loss: 1.290
# [38] loss: 1.287
# [39] loss: 1.283
# [40] loss: 1.275
# [41] loss: 1.267
# [42] loss: 1.258
# [43] loss: 1.250
# [44] loss: 1.245
# [45] loss: 1.241
# [46] loss: 1.236
# [47] loss: 1.232
# [48] loss: 1.228
# [49] loss: 1.223
# [50] loss: 1.219
# [51] loss: 1.214
# [52] loss: 1.210
# [53] loss: 1.206
# ...

# %% [markdown]
# # We see that the loss converges to around ~0.950, now we prepare the test data to try out our model

# %%
df_test = pd.read_csv('PS3_test.csv')

# %%
df_test['tokens'] = df_test['content'].apply(spacy_tokenizer)

# %%
df_test['vec'] = df_test['tokens'].apply(sent_vec)

# %%
df_test['tokens2'] = df_test['title'].apply(spacy_tokenizer)

# %%
df_test['vec2'] = df_test['tokens2'].apply(sent_vec)

# %%
df_test['vec'] += df_test['vec2']

# %%
x_test_df = df_test['vec']

# %%
df_test_copy=df_test

# %%
tensor_test=list()
for i in range(len(df_test_copy)):
  temp_tensor=df_test_copy['vec'][i]
  tensor_test.append(temp_tensor)

# %%
final_test_tensor=np.zeros(shape=(len(tensor_test),len(tensor_test[0])))
for i in range(len(tensor_test)):
  for j in range(len(tensor_test[0])):
    final_test_tensor[i][j]=tensor_test[i][j]

# %%
torch_test_tensor = torch.from_numpy(final_test_tensor)

# %%
y_pred = our_model(torch_test_tensor.to(torch.float32))

# %%
y_pred_probab=torch.softmax(y_pred,dim=1)

# %%
torch.argmax(y_pred_probab[7865])
# Out:
# tensor(133)

# %%
y_pred_probab.shape[0]
# Out:
# 8106

# %%
result=np.zeros(shape=(8106))
for i in range(y_pred_probab.shape[0]):
  result[i]=torch.argmax(y_pred_probab[i])

# %%
result  # the predictions of test_data based on our model
# Out:
#           0
# 0     361.0
# 1     351.0
# 2     351.0
# 3     244.0
# 4     351.0
# 5       8.0
# 6     326.0
# 7      59.0
# 8     168.0
# 9     397.0
# 10    420.0
# 11    297.0
# 12    287.0
# 13    361.0
# 14    158.0
# 15    437.0
# 16    164.0
# 17     54.0
# 18    132.0
# 19    220.0
# 20    392.0
# 21    201.0
# 22    397.0
# 23    132.0
# 24     97.0
# 25    351.0
# 26    276.0
# 27    132.0
# 28    456.0
# 29    356.0
# 30    351.0
# 31    269.0
# 32    427.0
# 33    351.0
# 34    305.0
# 35    270.0
# 36    355.0
# 37    361.0
# 38    243.0
# 39    358.0
# 40    311.0
# 41    290.0
# 42    145.0
# 43    209.0
# 44    453.0
# 45    487.0
# 46    403.0
# 47    208.0
# 48    238.0
# 49    351.0
# 50    122.0
# 51    383.0
# 52    405.0
# 53    249.0
# 54     41.0
# 55     36.0
# 56    428.0
# 57    499.0
# 58    351.0
# 59    315.0
# 60    269.0
# 61     36.0
# 62    314.0
# 63    127.0
# 64    410.0
# 65    264.0
# 66    117.0
# 67    119.0
# 68    351.0
# 69    130.0
# ...

# %%
type(x_train_df[0])
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
import tensorflow as tf

# %%
for i in range(0, len(x_train_df)):
  x_train_df[i] = x_train_df[i].numpy()
# Out:
# <ipython-input-111-b93bf41cf12f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train_df[i] = x_train_df[i].numpy()

# %%
x_train_df
# Out:
# 0        [-0.03805326526447878, 0.03756554652068575, -0...
# 1        [0.12171462364638636, 0.08967267923833781, -0....
# 2        [-0.11435368560081305, 0.05104876839837363, 0....
# 3        [0.08200368159959297, 0.08993350758272059, -0....
# 4        [0.03738945704997465, 0.3258000151597645, -0.0...
#                                ...
# 35107    [0.01318115234375, 0.040166015625, -0.02528564...
# 35108    [0.08679008185397105, 0.20474609149640344, -0....
# 35109    [0.13261050269717262, 0.018320477198040672, -0...
# 35110    [0.054639916670949834, 0.09964827821965803, -0...
# 35111    [-0.06124424112254176, 0.001545890798709662, -...
# Name: vec, Length: 35112, dtype: object

# %%
x_train_df = pd.DataFrame(x_train_df)

# %%
result = pd.DataFrame(result)

# %%
result.to_excel('PS3_train.xlsx', sheet_name = 'hi')

# %%
df_copy=x_train_df

# %%
df_copy.head()
# Out:
#                                                  vec
# 0  [-0.03805326526447878, 0.03756554652068575, -0...
# 1  [0.12171462364638636, 0.08967267923833781, -0....
# 2  [-0.11435368560081305, 0.05104876839837363, 0....
# 3  [0.08200368159959297, 0.08993350758272059, -0....
# 4  [0.03738945704997465, 0.3258000151597645, -0.0...

# %%
tensor=list()
for i in range(len(df_copy)):
  temp_tensor=df_copy['vec'][i]
  tensor.append(temp_tensor)

# %%
tensor

# %%
final_tensor=np.zeros(shape=(len(tensor),len(tensor[0])))
for i in range(len(tensor)):
  for j in range(len(tensor[0])):
    final_tensor[i][j]=tensor[i][j]

# %%
final_tensor2=pd.DataFrame(final_tensor)

# %%
final_tensor2.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.038053  0.037566 -0.196886  0.227269  0.048246  0.037726 -0.028368
# 1  0.121715  0.089673 -0.033505  0.172193  0.046429 -0.013817  0.070440
# 2 -0.114354  0.051049  0.024644  0.355035 -0.139114 -0.062406  0.009578
# 3  0.082004  0.089934 -0.077194  0.231226 -0.039009  0.054189 -0.073044
# 4  0.037389  0.325800 -0.041679  0.079416 -0.225703 -0.075679 -0.029849
#
#         7         8         9    ...       290       291       292       293  \
# 0 -0.211500  0.125569  0.042801  ... -0.091312  0.069413 -0.153015  0.049496
# 1 -0.120355  0.163923  0.146432  ... -0.040799 -0.102349 -0.046725 -0.065621
# 2 -0.176378  0.161207  0.124375  ... -0.047755  0.081501 -0.073553  0.055370
# 3 -0.187297  0.148079  0.187721  ... -0.066891  0.027532 -0.178404  0.077468
# 4 -0.319257  0.089674  0.215393  ... -0.115784  0.040227 -0.233691  0.094285
#
#         294       295       296       297       298       299
# ...

# %%
torch_tensor = torch.from_numpy(final_tensor)

# %%
target_tensor=np.zeros(shape=(len(tensor),1))
for i in range(len(tensor)):
  target_tensor[i]=y_train_df[i]

# %%
target_tensor
# Out:
# array([[247.],
#        [453.],
#        [228.],
#        ...,
#        [460.],
#        [158.],
#        [340.]])

# %%
target_tensor=torch.from_numpy(target_tensor).type(torch.float32)

# %%
target_tensor.squeeze(dim=1).shape
# Out:
# torch.Size([35112])

# %%
torch.reshape(target_tensor,(35112,))
# Out:
# tensor([247., 453., 228.,  ..., 460., 158., 340.])

# %%
target_tensor.shape
# Out:
# torch.Size([35112, 1])

# %%
# !pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #Transferring the result dataframe to an excel file

# %%
file_name = 'PS3-submission.xlsx'

# %%
result.to_excel('PS3-submission.xlsx')
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.
